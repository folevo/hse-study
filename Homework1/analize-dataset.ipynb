# %%
import sys
import types

# Обманываем Python и создаем поддельный модуль в памяти
if "pkg_resources" not in sys.modules:
    dummy = types.ModuleType("pkg_resources")
    dummy.get_distribution = lambda name: types.SimpleNamespace(version="0.0.0")
    dummy.declare_namespace = lambda name: None
    sys.modules["pkg_resources"] = dummy

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 4.1 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 6.6 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...

# %%
# !pip install ydata-profiling

# %%
import pandas as pd

# %%
DIAMOND_GOODS_DATASET = 'https://raw.githubusercontent.com/aiedu-courses/stepik_eda_and_dev_tools/main/datasets/diamonds_good.csv'

# %%
from ydata_profiling import ProfileReport

# %%
ds_r = pd.read_csv(DIAMOND_GOODS_DATASET)

# %%
profile_report = ProfileReport(ds_r, title = 'Report data set')

# %%
profile_report.to_file('goods_report.html')
# Out:
# /home/dzmitry_tsetsiaruk/my-study/.venv/lib/python3.12/site-packages/ydata_profiling/profile_report.py:365: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 167.45it/s]
